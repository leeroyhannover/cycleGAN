# %% [markdown]
# # Train 3D UNet on single molecule dataset; with deeper 3D Unet on dataset from 08.2022

# %% [markdown]
# ## load data

# %%
import os 
import numpy as np
# from dataGenerator import imageLoader
# from dataGenerator import imageLoaderDeep
from dataGenerator import imageLoader3D
import keras
import matplotlib.pyplot as plt
import glob
import random

# %%
# visualize

def visusalizeIMG(n_slice, test_img, test_msk):
    # n_slice = random.randint(0, test_img.shape[2])
    plt.figure(figsize=(8, 8))

    plt.subplot(121)
    plt.imshow(test_img[n_slice,:,:], cmap='gray')
    # plt.title('focal slice')
    plt.subplot(122)
    plt.imshow(test_msk[n_slice,:,:], cmap='gray')
    # plt.titSle('GT slice')
    plt.show()

# %%
# generate the gif

import numpy as np
from PIL import Image
import SimpleITK as sitk
import mrcfile

def saveGIF(imageGIF, labelGIF, predict, direction, gif_directory):
    
    # print('during gif') 
    
    imageGIF = imageGIF  # the original dataset is 8 bits
    stack = []
    
    # print(image.shape, label.shape, predict.shape)
    # print('image:', np.max(imageGIF), np.min(imageGIF))
    # print('label after gif: ', np.max(labelGIF), np.min(labelGIF))
    # print('predict: ', np.max(predict), np.min(predict))
    
    bar = np.ones((imageGIF.shape[0], 10)) # divide the images
    
    if direction == 0:
        print('cut along x')
    elif direction == 1:
        print('cut along y')

    elif direction == 2:
        print('cut along z')
        
    else:
        print('please specify the direction')
    
    
    for i in range(imageGIF.shape[0]):

        if direction == 0:
            temp1 = imageGIF[i,...]
            temp2 = predict[i,...]
            temp3 = labelGIF[i,...]
            
        elif direction == 1:
            temp1 = imageGIF[:,i,:]
            temp2 = predict[:,i,:]
            temp3 = labelGIF[:,i,:]
        
        elif direction == 2:
            temp1 = imageGIF[...,i]
            temp2 = predict[...,i]
            temp3 = labelGIF[...,i]
        else:
            print('illegal cut')
        
        
        # print('round:', i)
        # print('image concatenate:', temp1.shape)
        # print('label concatenate:', temp2.shape)
        # print('predict concatenate:', temp3.shape)
        
        imageTemp = np.concatenate((temp1, bar, temp2, bar, temp3), axis=1)
        # print('after concatenate:', imageTemp.shape)
        stack.append(imageTemp)
        
    stack = np.asarray(stack)
    
    # imgs = [img*255 for img in stack]
    imgs = [Image.fromarray(img*255) for img in stack]  # pil要求整体图片乘上255
    # duration is the number of milliseconds between frames; this is 40 frames per second
    imgs[0].save(gif_directory, save_all=True, append_images=imgs[1:], duration=50, loop=0)
    
    # write as nii
    # writer = sitk.ImageFileWriter()
    # writer.SetFileName('./results/result.nii')
    # writer.Execute(stack)
    
    mrc = mrcfile.new('./results/result.mrc', overwrite=True)
    mrc.set_data((stack*255).astype('int8'))
    mrc.close
    
    np.save('./results/result.npy', stack)

# %%
# specify the dir

DATA_PATH = 'E:/EM/demo/3D_Unet_keras/data/2022_07/inputData/'

train_img_dir = DATA_PATH + 'train/images/'
train_msk_dir = DATA_PATH + 'train/masks/'

train_img_list = sorted(glob.glob(train_img_dir + '/*.npy'))
train_msk_list = sorted(glob.glob(train_msk_dir + '/*.npy'))

num_images = len(train_img_list)
print(num_images)
# Out:
# 240

# %%
print('image list:', train_img_list[10])
print('mask list:', train_msk_list[10])
# Out:
# image list: E:/EM/demo/3D_Unet_keras/data/2022_07/inputData/train/images\image_110.npy
# mask list: E:/EM/demo/3D_Unet_keras/data/2022_07/inputData/train/masks\mask_110.npy

# %%
# visualize the images

img_num = random.randint(0, num_images-1) # num从1开始
test_img = np.load(train_img_list[img_num])
test_img = test_img[...,0]
print('image shape:', test_img.shape)

test_mask = np.load(train_msk_list[img_num])
print('before mask:', test_mask.shape)
test_mask = np.argmax(test_mask, axis=3)
print('after mask:', test_mask.shape)
# Out:
# image shape: (64, 64, 64)
# before mask: (64, 64, 64, 2)
# after mask: (64, 64, 64)

# %%
#  reshape data for 2D deep UNet

# test = np.stack([test_mask], axis=3)
# print(test.shape)
test = np.expand_dims(test_mask, axis = -1)
print(test.shape)
# Out:
# (64, 64, 64, 1)

# %%
# visualize the images 

# n_slice = random.randint(0, test_mask.shape[2]-1)

n_slice = 32
print('current slice:', n_slice)
visusalizeIMG(n_slice, test_img, test_mask)

print('current slice:', n_slice + 2)
visusalizeIMG(n_slice + 2, test_img, test_mask)
# Out:
# current slice: 32
# current slice: 34

# %% [markdown]
# ### calculate the weight between labels. useful for weighted dice loss

# %%
import pandas as pd

columns = ['0', '1']
df = pd.DataFrame(columns=columns)

train_msk_list = sorted(glob.glob(train_msk_dir + '/*.npy'))

for img in range(len(train_msk_list)):
    
    # print(img)
    temp_image = np.load(train_msk_list[img])
    temp_image = np.argmax(temp_image, axis=3)  # convert back into images
    
    val, counts = np.unique(temp_image, return_counts=True) # count labels
    zipped = zip(columns, counts)
    counts_dict = dict(zipped)
    
    df = df.append(counts_dict, ignore_index = True)

# %%
# calculate the ratio of different labels

label_0 = df['0'].sum()
label_1 = df['1'].sum()

total_labels = label_0 + label_1
n_classes = 2

# class weight calculated: n_samples / (n_classes * n_samples_for_class)
wt0 = round((total_labels/(n_classes*label_0)), 2) # 小数点后两位
wt1 = round((total_labels/(n_classes*label_1)), 2)

print(wt0, wt1)
# Out:
# 0.56 4.4

# %% [markdown]
# ## Define the image generator

# %%
# data path and sort

from natsort import natsorted

DATA_PATH = 'E:/EM/demo/3D_Unet_keras/data/2022_07/inputData/'

train_img_dir = DATA_PATH + 'train/images/'
train_msk_dir = DATA_PATH + 'train/masks/'

train_img_list = natsorted(os.listdir(train_img_dir))
train_msk_list = natsorted(os.listdir(train_msk_dir))

# validation
val_img_dir = DATA_PATH + 'val/images/'
val_msk_dir = DATA_PATH + 'val/masks/'

val_img_list = natsorted(os.listdir(val_img_dir))
val_msk_list = natsorted(os.listdir(val_msk_dir))

# testing
test_img_dir = DATA_PATH + 'test/images/'
test_msk_dir = DATA_PATH + 'test/masks/'

test_img_list = natsorted(os.listdir(test_img_dir))
test_msk_list = natsorted(os.listdir(test_msk_dir))

print('train images:', len(train_img_list))
print('val images:', len(val_img_list))
print('test images:', len(test_img_list))

# %%
# data generator for training

batch_size = 2

train_img_datagen = imageLoader3D(train_img_dir, train_img_list,
                               train_msk_dir, train_msk_list, batch_size)

val_img_datagen = imageLoader3D(val_img_dir, val_img_list,
                             val_msk_dir, val_msk_list, batch_size)

# %%
# visualize the data generator

img, msk = train_img_datagen.__next__()
print('image gen:', img.shape)
print('mask gen:', msk.shape)

stack_num = random.randint(0, img.shape[0]-1)
test_img = np.squeeze(img[stack_num,...])
test_mask = np.squeeze(msk[stack_num,...])
print(test_img.shape)

n_slice=random.randint(0, test_mask.shape[1]-1)
# n_slice = 50

print('slice num:', n_slice)
visusalizeIMG(n_slice, test_mask, test_img)
# Out:
# image gen: (2, 64, 64, 64, 1)
# mask gen: (2, 64, 64, 64, 1)
# (64, 64, 64)
# slice num: 2

# %% [markdown]
# ## Define the loss, metrics and optimizer for training

# %%
# wt0, wt1 = 0.5,0.5
wt0, wt1 = 0.56,4.4

import segmentation_models_3D as sm

dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1]))  # default is uniform
focal_loss = sm.losses.CategoricalFocalLoss()
BCE_loss = sm.losses.BinaryCELoss()

total_loss = dice_loss*0.005 + (1* focal_loss) + BCE_loss*1  # works for most segmentation jobs

# metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]  # metrics for final performance
metrics = [sm.metrics.IOUScore(threshold=0.5)]  # metrics for final performance
# metrics = ['accuracy', sm.metrics.FScore(beta=1)] # F1 score

LR = 0.0001
optim = keras.optimizers.Adam(LR)
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
# 调试用loss function

# loss function designed from scratch

# import tensorflow as tf
# import tensorflow.keras.backend as K

# LR = 0.0001
# optim = keras.optimizers.Adam(LR)


# # soft dice
# def dice_coef(y_true, y_pred, smooth=100):        
#     y_true_f = K.flatten(y_true)
#     y_pred_f = K.flatten(y_pred)
#     intersection = K.sum(y_true_f * y_pred_f)
#     dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
#     return dice


# def loss_function(y_true, y_pred):
#     dice_loss = -dice_coef(y_true, y_pred)
#     l1_loss = tf.math.reduce_mean(tf.math.abs(y_true - y_pred), axis=(1,2,3))  # tranfer matrix into value
#     SCE = tf.keras.metrics.binary_crossentropy(y_true, y_pred, from_logits=False, label_smoothing=0.0, axis=-1)
    
#     # print('SCE shape:', SCE.shape)
    
#     # ssim_loss = tf.image.ssim_multiscale(y_true, y_pred, max_val=1)
    
#     total_loss = dice_loss*0.05 + l1_loss*0.5  + tf.math.reduce_mean(SCE, axis=(1,2))*1  #CE_loss #ssim_loss    # weight should be tuned SCE #
    
    
#     return total_loss

# jaccard_loss = JaccardLoss()
# dice_loss = DiceLoss()

# binary_focal_loss = BinaryFocalLoss()
# categorical_focal_loss = CategoricalFocalLoss()

# binary_crossentropy = BinaryCELoss()
# categorical_crossentropy = CategoricalCELoss()

# # loss combinations
# bce_dice_loss = binary_crossentropy + dice_loss
# bce_jaccard_loss = binary_crossentropy + jaccard_loss

# cce_dice_loss = categorical_crossentropy + dice_loss
# cce_jaccard_loss = categorical_crossentropy + jaccard_loss

# binary_focal_dice_loss = binary_focal_loss + dice_loss
# binary_focal_jaccard_loss = binary_focal_loss + jaccard_loss

# categorical_focal_dice_loss = categorical_focal_loss + dice_loss
# categorical_focal_jaccard_loss = categorical_focal_loss + jaccard_loss

# %% [markdown]
# ## Fit the model

# %%
steps_per_epoch = len(train_img_list) // batch_size
val_steps_per_epoch = len(val_img_list) // batch_size

# %%
# load model from transfer learning

from model.simple3DUnet_512 import simple_unet_model

model = simple_unet_model(IMG_HEIGHT=64,
                         IMG_WIDTH=64,
                         IMG_DEPTH=64,
                         IMG_CHANNELS=1,
                         num_classes=1)   # change the num; 2->1. G.

model.compile(optimizer=optim, loss=total_loss, metrics=metrics)
# model.compile(optimizer=optim, loss=loss_function, metrics=[dice_coef]) 

# print(model.summary())
print(model.input_shape)
print(model.output_shape)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 64,  0           []
#                                  3)]
#
#  conv3d (Conv3D)                (None, 64, 64, 64,   1312        ['input_1[0][0]']
#                                 16)
#
#  instance_normalization (Instan  (None, 64, 64, 64,   32         ['conv3d[0][0]']
#  ceNormalization)               16)
#
#  conv3d_1 (Conv3D)              (None, 64, 64, 64,   6928        ['instance_normalization[0][0]']
#                                 16)
#
#  instance_normalization_1 (Inst  (None, 64, 64, 64,   32         ['conv3d_1[0][0]']
#  anceNormalization)             16)
#
#  max_pooling3d (MaxPooling3D)   (None, 32, 32, 32,   0           ['instance_normalization_1[0][0]'
#                                 16)                              ]
#
#  conv3d_2 (Conv3D)              (None, 32, 32, 32,   13856       ['max_pooling3d[0][0]']
#                                 32)
#
#  instance_normalization_2 (Inst  (None, 32, 32, 32,   64         ['conv3d_2[0][0]']
#  anceNormalization)             32)
#
#  conv3d_3 (Conv3D)              (None, 32, 32, 32,   27680       ['instance_normalization_2[0][0]'
#                                 32)                              ]
#
#  instance_normalization_3 (Inst  (None, 32, 32, 32,   64         ['conv3d_3[0][0]']
#  anceNormalization)             32)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 16, 16, 16,   0          ['instance_normalization_3[0][0]'
#                                 32)                              ]
#
#  conv3d_4 (Conv3D)              (None, 16, 16, 16,   55360       ['max_pooling3d_1[0][0]']
#                                 64)
#
#  instance_normalization_4 (Inst  (None, 16, 16, 16,   128        ['conv3d_4[0][0]']
#  anceNormalization)             64)
#
#  conv3d_5 (Conv3D)              (None, 16, 16, 16,   110656      ['instance_normalization_4[0][0]'
#                                 64)                              ]
#
#  instance_normalization_5 (Inst  (None, 16, 16, 16,   128        ['conv3d_5[0][0]']
#  anceNormalization)             64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 8, 8, 8, 64)  0          ['instance_normalization_5[0][0]'
#                                                                  ]
#
#  conv3d_6 (Conv3D)              (None, 8, 8, 8, 128  221312      ['max_pooling3d_2[0][0]']
#                                 )
#
#  instance_normalization_6 (Inst  (None, 8, 8, 8, 128  256        ['conv3d_6[0][0]']
#  anceNormalization)             )
#
#  conv3d_7 (Conv3D)              (None, 8, 8, 8, 128  442496      ['instance_normalization_6[0][0]'
#                                 )                                ]
#
#  instance_normalization_7 (Inst  (None, 8, 8, 8, 128  256        ['conv3d_7[0][0]']
#  anceNormalization)             )
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 4, 4, 4, 128  0          ['instance_normalization_7[0][0]'
#                                 )                                ]
#
#  conv3d_8 (Conv3D)              (None, 4, 4, 4, 256  884992      ['max_pooling3d_3[0][0]']
#                                 )
#
#  instance_normalization_8 (Inst  (None, 4, 4, 4, 256  512        ['conv3d_8[0][0]']
#  anceNormalization)             )
#
#  conv3d_9 (Conv3D)              (None, 4, 4, 4, 256  1769728     ['instance_normalization_8[0][0]'
#                                 )                                ]
#
#  instance_normalization_9 (Inst  (None, 4, 4, 4, 256  512        ['conv3d_9[0][0]']
#  anceNormalization)             )
#
#  max_pooling3d_4 (MaxPooling3D)  (None, 2, 2, 2, 256  0          ['instance_normalization_9[0][0]'
#                                 )                                ]
#
#  conv3d_10 (Conv3D)             (None, 2, 2, 2, 512  3539456     ['max_pooling3d_4[0][0]']
#                                 )
#
#  instance_normalization_10 (Ins  (None, 2, 2, 2, 512  1024       ['conv3d_10[0][0]']
#  tanceNormalization)            )
#
#  conv3d_11 (Conv3D)             (None, 2, 2, 2, 512  7078400     ['instance_normalization_10[0][0]
#                                 )                                ']
#
#  instance_normalization_11 (Ins  (None, 2, 2, 2, 512  1024       ['conv3d_11[0][0]']
#  tanceNormalization)            )
#
#  conv3d_transpose (Conv3DTransp  (None, 4, 4, 4, 256  1048832    ['instance_normalization_11[0][0]
#  ose)                           )                                ']
#
#  concatenate (Concatenate)      (None, 4, 4, 4, 512  0           ['conv3d_transpose[0][0]',
#                                 )                                 'instance_normalization_9[0][0]'
#                                                                  ]
#
#  conv3d_12 (Conv3D)             (None, 4, 4, 4, 256  3539200     ['concatenate[0][0]']
#                                 )
#
#  instance_normalization_12 (Ins  (None, 4, 4, 4, 256  512        ['conv3d_12[0][0]']
#  tanceNormalization)            )
#
#  conv3d_13 (Conv3D)             (None, 4, 4, 4, 256  1769728     ['instance_normalization_12[0][0]
#                                 )                                ']
#
#  instance_normalization_13 (Ins  (None, 4, 4, 4, 256  512        ['conv3d_13[0][0]']
#  tanceNormalization)            )
#
#  conv3d_transpose_1 (Conv3DTran  (None, 8, 8, 8, 128  262272     ['instance_normalization_13[0][0]
#  spose)                         )                                ']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 8, 256  0           ['conv3d_transpose_1[0][0]',
#                                 )                                 'instance_normalization_7[0][0]'
#                                                                  ]
#
#  conv3d_14 (Conv3D)             (None, 8, 8, 8, 128  884864      ['concatenate_1[0][0]']
#                                 )
#
#  conv3d_15 (Conv3D)             (None, 8, 8, 8, 128  442496      ['conv3d_14[0][0]']
#                                 )
#
#  instance_normalization_14 (Ins  (None, 8, 8, 8, 128  256        ['conv3d_15[0][0]']
#  tanceNormalization)            )
#
#  conv3d_transpose_2 (Conv3DTran  (None, 16, 16, 16,   65600      ['instance_normalization_14[0][0]
#  spose)                         64)                              ']
#
#  concatenate_2 (Concatenate)    (None, 16, 16, 16,   0           ['conv3d_transpose_2[0][0]',
#                                 128)                              'instance_normalization_5[0][0]'
#                                                                  ]
#
#  conv3d_16 (Conv3D)             (None, 16, 16, 16,   221248      ['concatenate_2[0][0]']
#                                 64)
#
#  conv3d_17 (Conv3D)             (None, 16, 16, 16,   110656      ['conv3d_16[0][0]']
#                                 64)
#
#  instance_normalization_15 (Ins  (None, 16, 16, 16,   128        ['conv3d_17[0][0]']
#  tanceNormalization)            64)
#
#  conv3d_transpose_3 (Conv3DTran  (None, 32, 32, 32,   16416      ['instance_normalization_15[0][0]
#  spose)                         32)                              ']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_3[0][0]',
#                                 64)                               'instance_normalization_3[0][0]'
#                                                                  ]
#
#  conv3d_18 (Conv3D)             (None, 32, 32, 32,   55328       ['concatenate_3[0][0]']
#                                 32)
#
#  conv3d_19 (Conv3D)             (None, 32, 32, 32,   27680       ['conv3d_18[0][0]']
#                                 32)
#
#  instance_normalization_16 (Ins  (None, 32, 32, 32,   64         ['conv3d_19[0][0]']
#  tanceNormalization)            32)
#
#  conv3d_transpose_4 (Conv3DTran  (None, 64, 64, 64,   4112       ['instance_normalization_16[0][0]
#  spose)                         16)                              ']
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_4[0][0]',
#                                 32)                               'instance_normalization_1[0][0]'
#                                                                  ]
#
#  conv3d_20 (Conv3D)             (None, 64, 64, 64,   13840       ['concatenate_4[0][0]']
#                                 16)
#
#  conv3d_21 (Conv3D)             (None, 64, 64, 64,   6928        ['conv3d_20[0][0]']
#                                 16)
#
#  instance_normalization_17 (Ins  (None, 64, 64, 64,   32         ['conv3d_21[0][0]']
#  tanceNormalization)            16)
#
#  conv3d_22 (Conv3D)             (None, 64, 64, 64,   34          ['instance_normalization_17[0][0]
#                                 2)                               ']
#
# ==================================================================================================
# Total params: 22,626,946
# Trainable params: 22,626,946
# Non-trainable params: 0
# __________________________________________________________________________________________________
# (None, 64, 64, 64, 3)
# (None, 64, 64, 64, 2)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 64,  0           []
#                                  1)]
#
#  conv3d_23 (Conv3D)             (None, 64, 64, 64,   448         ['input_2[0][0]']
#                                 16)
#
#  instance_normalization_18 (Ins  (None, 64, 64, 64,   32         ['conv3d_23[0][0]']
#  tanceNormalization)            16)
#
#  conv3d_24 (Conv3D)             (None, 64, 64, 64,   6928        ['instance_normalization_18[0][0]
#                                 16)                              ']
#
#  instance_normalization_19 (Ins  (None, 64, 64, 64,   32         ['conv3d_24[0][0]']
#  tanceNormalization)            16)
#
#  max_pooling3d_5 (MaxPooling3D)  (None, 32, 32, 32,   0          ['instance_normalization_19[0][0]
#                                 16)                              ']
#
#  conv3d_25 (Conv3D)             (None, 32, 32, 32,   13856       ['max_pooling3d_5[0][0]']
#                                 32)
#
#  instance_normalization_20 (Ins  (None, 32, 32, 32,   64         ['conv3d_25[0][0]']
#  tanceNormalization)            32)
#
#  conv3d_26 (Conv3D)             (None, 32, 32, 32,   27680       ['instance_normalization_20[0][0]
#                                 32)                              ']
#
#  instance_normalization_21 (Ins  (None, 32, 32, 32,   64         ['conv3d_26[0][0]']
#  tanceNormalization)            32)
#
#  max_pooling3d_6 (MaxPooling3D)  (None, 16, 16, 16,   0          ['instance_normalization_21[0][0]
#                                 32)                              ']
#
#  conv3d_27 (Conv3D)             (None, 16, 16, 16,   55360       ['max_pooling3d_6[0][0]']
#                                 64)
#
#  instance_normalization_22 (Ins  (None, 16, 16, 16,   128        ['conv3d_27[0][0]']
#  tanceNormalization)            64)
#
#  conv3d_28 (Conv3D)             (None, 16, 16, 16,   110656      ['instance_normalization_22[0][0]
#                                 64)                              ']
#
#  instance_normalization_23 (Ins  (None, 16, 16, 16,   128        ['conv3d_28[0][0]']
#  tanceNormalization)            64)
#
#  max_pooling3d_7 (MaxPooling3D)  (None, 8, 8, 8, 64)  0          ['instance_normalization_23[0][0]
#                                                                  ']
#
#  conv3d_29 (Conv3D)             (None, 8, 8, 8, 128  221312      ['max_pooling3d_7[0][0]']
#                                 )
#
#  instance_normalization_24 (Ins  (None, 8, 8, 8, 128  256        ['conv3d_29[0][0]']
#  tanceNormalization)            )
#
#  conv3d_30 (Conv3D)             (None, 8, 8, 8, 128  442496      ['instance_normalization_24[0][0]
#                                 )                                ']
#
#  instance_normalization_25 (Ins  (None, 8, 8, 8, 128  256        ['conv3d_30[0][0]']
#  tanceNormalization)            )
#
#  max_pooling3d_8 (MaxPooling3D)  (None, 4, 4, 4, 128  0          ['instance_normalization_25[0][0]
#                                 )                                ']
#
#  conv3d_31 (Conv3D)             (None, 4, 4, 4, 256  884992      ['max_pooling3d_8[0][0]']
#                                 )
#
#  instance_normalization_26 (Ins  (None, 4, 4, 4, 256  512        ['conv3d_31[0][0]']
#  tanceNormalization)            )
#
#  conv3d_32 (Conv3D)             (None, 4, 4, 4, 256  1769728     ['instance_normalization_26[0][0]
#                                 )                                ']
#
#  instance_normalization_27 (Ins  (None, 4, 4, 4, 256  512        ['conv3d_32[0][0]']
#  tanceNormalization)            )
#
#  max_pooling3d_9 (MaxPooling3D)  (None, 2, 2, 2, 256  0          ['instance_normalization_27[0][0]
#                                 )                                ']
#
#  conv3d_33 (Conv3D)             (None, 2, 2, 2, 512  3539456     ['max_pooling3d_9[0][0]']
#                                 )
#
#  instance_normalization_28 (Ins  (None, 2, 2, 2, 512  1024       ['conv3d_33[0][0]']
#  tanceNormalization)            )
#
#  conv3d_34 (Conv3D)             (None, 2, 2, 2, 512  7078400     ['instance_normalization_28[0][0]
#                                 )                                ']
#
#  instance_normalization_29 (Ins  (None, 2, 2, 2, 512  1024       ['conv3d_34[0][0]']
#  tanceNormalization)            )
#
#  conv3d_transpose_5 (Conv3DTran  (None, 4, 4, 4, 256  1048832    ['instance_normalization_29[0][0]
#  spose)                         )                                ']
#
#  concatenate_5 (Concatenate)    (None, 4, 4, 4, 512  0           ['conv3d_transpose_5[0][0]',
#                                 )                                 'instance_normalization_27[0][0]
#                                                                  ']
#
#  conv3d_35 (Conv3D)             (None, 4, 4, 4, 256  3539200     ['concatenate_5[0][0]']
#                                 )
#
#  instance_normalization_30 (Ins  (None, 4, 4, 4, 256  512        ['conv3d_35[0][0]']
#  tanceNormalization)            )
#
#  conv3d_36 (Conv3D)             (None, 4, 4, 4, 256  1769728     ['instance_normalization_30[0][0]
#                                 )                                ']
#
#  instance_normalization_31 (Ins  (None, 4, 4, 4, 256  512        ['conv3d_36[0][0]']
#  tanceNormalization)            )
#
#  conv3d_transpose_6 (Conv3DTran  (None, 8, 8, 8, 128  262272     ['instance_normalization_31[0][0]
#  spose)                         )                                ']
#
#  concatenate_6 (Concatenate)    (None, 8, 8, 8, 256  0           ['conv3d_transpose_6[0][0]',
#                                 )                                 'instance_normalization_25[0][0]
#                                                                  ']
#
#  conv3d_37 (Conv3D)             (None, 8, 8, 8, 128  884864      ['concatenate_6[0][0]']
#                                 )
#
#  conv3d_38 (Conv3D)             (None, 8, 8, 8, 128  442496      ['conv3d_37[0][0]']
#                                 )
#
#  instance_normalization_32 (Ins  (None, 8, 8, 8, 128  256        ['conv3d_38[0][0]']
#  tanceNormalization)            )
#
#  conv3d_transpose_7 (Conv3DTran  (None, 16, 16, 16,   65600      ['instance_normalization_32[0][0]
#  spose)                         64)                              ']
#
#  concatenate_7 (Concatenate)    (None, 16, 16, 16,   0           ['conv3d_transpose_7[0][0]',
#                                 128)                              'instance_normalization_23[0][0]
#                                                                  ']
#
#  conv3d_39 (Conv3D)             (None, 16, 16, 16,   221248      ['concatenate_7[0][0]']
#                                 64)
#
#  conv3d_40 (Conv3D)             (None, 16, 16, 16,   110656      ['conv3d_39[0][0]']
#                                 64)
#
#  instance_normalization_33 (Ins  (None, 16, 16, 16,   128        ['conv3d_40[0][0]']
#  tanceNormalization)            64)
#
#  conv3d_transpose_8 (Conv3DTran  (None, 32, 32, 32,   16416      ['instance_normalization_33[0][0]
#  spose)                         32)                              ']
#
#  concatenate_8 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_8[0][0]',
#                                 64)                               'instance_normalization_21[0][0]
#                                                                  ']
#
#  conv3d_41 (Conv3D)             (None, 32, 32, 32,   55328       ['concatenate_8[0][0]']
#                                 32)
#
#  conv3d_42 (Conv3D)             (None, 32, 32, 32,   27680       ['conv3d_41[0][0]']
#                                 32)
#
#  instance_normalization_34 (Ins  (None, 32, 32, 32,   64         ['conv3d_42[0][0]']
#  tanceNormalization)            32)
#
#  conv3d_transpose_9 (Conv3DTran  (None, 64, 64, 64,   4112       ['instance_normalization_34[0][0]
#  spose)                         16)                              ']
#
#  concatenate_9 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_9[0][0]',
#                                 32)                               'instance_normalization_19[0][0]
#                                                                  ']
#
#  conv3d_43 (Conv3D)             (None, 64, 64, 64,   13840       ['concatenate_9[0][0]']
#                                 16)
#
#  conv3d_44 (Conv3D)             (None, 64, 64, 64,   6928        ['conv3d_43[0][0]']
#                                 16)
#
#  instance_normalization_35 (Ins  (None, 64, 64, 64,   32         ['conv3d_44[0][0]']
#  tanceNormalization)            16)
#
#  conv3d_45 (Conv3D)             (None, 64, 64, 64,   17          ['instance_normalization_35[0][0]
#                                 1)                               ']
#
# ==================================================================================================
# Total params: 22,626,065
# Trainable params: 22,626,065
# Non-trainable params: 0
# __________________________________________________________________________________________________
# (None, 64, 64, 64, 1)
# (None, 64, 64, 64, 1)

# %% [markdown]
# ## Train and save model

# %% [markdown]
# #### 测试batch 训练

# %%
# 测试per batch
# train_on_batch

NUM_STEPS = 1000

# model.summary()

for step in range(NUM_STEPS):
    
    img, msk = train_img_datagen.__next__()
    # msk = np.argmax(msk, axis=-1).astype('float64') 
    # msk = np.expand_dims(msk, axis=4) # keep the shape [None, W, H, D, CH=1]
    
    # img = np.squeeze(img)
    # msk = np.argmax(msk, axis=-1).astype('float64')  # remove last channel
    # msk = np.expand_dims(mBCE_lossaxis=-1).astype('float64')
    
    loss = model.train_on_batch(img, msk)  # control the way to consume MM
    
    # print(step, loss)
    
    if step % 1000 == 0:
        # model.save_weights('./modelDeep_loss.hdf5')
        model.save('./weight/modelDeep_3D_512_batch1.hdf5')  # directly save the whole model
        
    if step % 100 == 0:
        prediction = model.predict(img,batch_size=1)
        # print(prediction.shape, msk.shape)
        # print(prediction[0,:,32,:,:].shape, msk[0,:,32,:].shape)
        print(step, loss)
        plt.imshow(np.concatenate((np.squeeze(prediction[0,:,32,:,:]), np.squeeze( msk[0,:,32,:,:])), axis=1),cmap='gray')
        plt.show()
        plt.close('all')
# Out:
# 2/2 [==============================] - 1s 10ms/step
# 0 [0.9084247946739197, 0.08806560188531876]
# 2/2 [==============================] - 0s 25ms/step
# 100 [0.6036011576652527, 0.3553515076637268]
# 2/2 [==============================] - 0s 23ms/step
# 200 [0.5796549320220947, 0.3781950771808624]
# 2/2 [==============================] - 0s 24ms/step
# 300 [0.5619676113128662, 0.382631778717041]
# 2/2 [==============================] - 0s 25ms/step
# 400 [0.5357760787010193, 0.3887074887752533]
# 2/2 [==============================] - 0s 22ms/step
# 500 [0.5185363292694092, 0.3879051208496094]
# 2/2 [==============================] - 0s 25ms/step
# 600 [0.4947831630706787, 0.3978453576564789]
# 2/2 [==============================] - 0s 25ms/step
# 700 [0.47153404355049133, 0.40534037351608276]
# 2/2 [==============================] - 0s 24ms/step
# 800 [0.44584086537361145, 0.42238616943359375]
# 2/2 [==============================] - 0s 27ms/step
# 900 [0.42034032940864563, 0.43994271755218506]

# %%
# visualize of last training images

showPred = prediction
showMask = msk
showIMG = img
print(showPred.shape, showMask.shape)
n_slice = random.randint(0, showPred.shape[1])

NUM = 0
print('slice Num:', n_slice)
visusalizeIMG(n_slice, showPred[NUM,...], showMask[NUM,...])

# %%
# generate one gif of the stack

NUM = 0
direction = 0
gif_directory = './results/result.gif'

saveGIF(showIMG[NUM,...].squeeze(), showMask[NUM,...].squeeze(), showPred[NUM,...].squeeze(), direction, gif_directory)

# %% [markdown]
# #### Train in fit

# %%
import tensorflow.keras as k

callbacks = [
    k.callbacks.EarlyStopping(patience=15, monitor='val_loss'),
    k.callbacks.TensorBoard(log_dir = './tensorBoard/3D/512/')]

# %%
# original model
EPOCHS = 10

history = model.fit(train_img_datagen,
                   steps_per_epoch=steps_per_epoch,
                   epochs=EPOCHS,
                   verbose=1, # ??
                   validation_data=val_img_datagen,
                   validation_steps=val_steps_per_epoch, callbacks=callbacks)


MODEL_PATH = 'E:/EM/demo/3D_Unet_keras/weight/'

model.save(MODEL_PATH + 'deep_3d_512' + '_' + str(EPOCHS) + '.hdf5')
# Out:
# Epoch 1/10
# 120/120 [==============================] - 31s 184ms/step - loss: 0.6578 - iou_score: 0.2812 - val_loss: 0.6016 - val_iou_score: 0.3563
# Epoch 2/10
# 120/120 [==============================] - 21s 179ms/step - loss: 0.5876 - iou_score: 0.3679 - val_loss: 0.5726 - val_iou_score: 0.3785
# Epoch 3/10
# 120/120 [==============================] - 21s 178ms/step - loss: 0.5605 - iou_score: 0.3814 - val_loss: 0.5467 - val_iou_score: 0.3860
# Epoch 4/10
# 120/120 [==============================] - 21s 179ms/step - loss: 0.5345 - iou_score: 0.3882 - val_loss: 0.5209 - val_iou_score: 0.3916
# Epoch 5/10
# 120/120 [==============================] - 22s 180ms/step - loss: 0.5083 - iou_score: 0.3941 - val_loss: 0.4951 - val_iou_score: 0.3966
# Epoch 6/10
# 120/120 [==============================] - 22s 180ms/step - loss: 0.4818 - iou_score: 0.4003 - val_loss: 0.4700 - val_iou_score: 0.4003
# Epoch 7/10
# 120/120 [==============================] - 22s 181ms/step - loss: 0.4553 - iou_score: 0.4067 - val_loss: 0.4463 - val_iou_score: 0.4018
# Epoch 8/10
# 120/120 [==============================] - 22s 181ms/step - loss: 0.4289 - iou_score: 0.4143 - val_loss: 0.4240 - val_iou_score: 0.4018
# Epoch 9/10
# 120/120 [==============================] - 22s 181ms/step - loss: 0.4028 - iou_score: 0.4240 - val_loss: 0.4033 - val_iou_score: 0.4016
# Epoch 10/10
# 120/120 [==============================] - 22s 182ms/step - loss: 0.3781 - iou_score: 0.4331 - val_loss: 0.3850 - val_iou_score: 0.3949

# %% [markdown]
# ## Visualize the training process

# %%
FIG_PATH = './reports/'

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.figure()
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig(FIG_PATH + 'loss_3D_512.png', dpi=300, bbox_inches = 'tight')
plt.show()


# acc = history.history['accuracy']
# val_acc = history.history['val_accuracy']

# plt.plot(epochs, acc, 'y', label='Training accuracy')
# plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
# plt.title('Training and validation accuracy')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()

# IoU
IoU = history.history['iou_score']
val_iou = history.history['val_iou_score']
plt.figure()
plt.plot(epochs, IoU, 'y', label='Training IOU')
plt.plot(epochs, val_iou, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.savefig(FIG_PATH + 'IoU_3D_512.png', dpi=300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Predict the test dataset of single image

# %%
# load in the model

from keras.models import load_model

MODEL_PATH = 'E:/EM/demo/3D_Unet_keras/weight/'

my_model = load_model(MODEL_PATH + 'deep_3d_512' + '_' + str(EPOCHS) + '.hdf5', compile=False)
# my_model = load_model('./weight/deep_3D_512_50.hdf5', compile=False)

# %%
# for prediction verify IoU

from keras.metrics import MeanIoU

batch_size = 4  # prediction batch

test_img_datagen = imageLoader3D(test_img_dir, test_img_list,
                              test_msk_dir, test_msk_list, batch_size)

# %%
# verify the generator

test_image_batch, test_mask_batch = test_img_datagen.__next__()  
print('before:', test_mask_batch.shape)
# test_mask_batch_argmax = np.argmax(test_mask_batch, axis=4) # convert onehot back to integer
# print('after:', test_mask_batch_argmax.shape)
# Out:
# before: (4, 64, 64, 64, 1)

# %%
# predict

test_pred_batch = my_model.predict(test_image_batch)
print(test_pred_batch.shape)
test_pred_batch = np.expand_dims(np.squeeze(test_pred_batch), axis=4)
print(test_pred_batch.shape, test_mask_batch.shape)
# Out:
# 1/1 [==============================] - 1s 1s/step
# (4, 64, 64, 64, 1)
# (4, 64, 64, 64, 1) (4, 64, 64, 64, 1)

# %%
# n_classes = 2

n_classesG = 2
IOU_keras = MeanIoU(num_classes=n_classesG)  
IOU_keras.update_state(np.squeeze(test_pred_batch), np.squeeze(test_mask_batch))
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.44199085

# %% [markdown]
# ## Predict the test dataset of multiple image

# %%
img_num = 15  # the name in test dataset

test_img = np.load(DATA_PATH + '/test/images/image_'+str(img_num)+'.npy')

test_mask = np.load(DATA_PATH + '/test/masks/mask_'+str(img_num)+'.npy')
# print(test_img.shape, test_mask.shape)
test_mask_argmax = np.argmax(test_mask, axis=3)
# test_mask_argmax = np.expand_dims(test_mask_argmax, axis=3)
print(test_img.shape, test_mask_argmax.shape)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = my_model.predict(test_img_input)
test_prediction = np.squeeze(test_prediction[0,...])
print(test_prediction.shape)
# Out:
# (64, 64, 64, 1) (64, 64, 64)
# 1/1 [==============================] - 1s 613ms/step
# (64, 64, 64)

# %%
# visualize in x direction

n_slice = 32

plt.figure(figsize=(8, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[n_slice,:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[n_slice,:,:], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction[n_slice,:,:], cmap='gray')
plt.show()

# %%
# visualize in y direction

n_slice = 32

plt.figure(figsize=(8, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,n_slice,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,n_slice,:], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction[:,n_slice,:], cmap='gray')
plt.show()
